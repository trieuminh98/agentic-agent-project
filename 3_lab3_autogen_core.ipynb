# %% [markdown]
# ### And now - Week 3 Day 3
#
# ## AutoGen Core
#
# Something a little different.
#
# This is agnostic to the underlying Agent framework
#
# You can use AutoGen AgentChat, or you can use something else; it's an Agent interaction framework.
#
# From that point of view, it's positioned similarly to LangGraph.
#
# ### The fundamental principle
#
# Autogen Core decouples an agent's logic from how messages are delivered.
# The framework provides a communication infrastructure, along with agent lifecycle, and the agents are responsible for their own work.
#
# The communication infrastructure is called a Runtime.
#
# There are 2 types: **Standalone** and **Distributed**.
#
# Today we will use a standalone runtime: the **SingleThreadedAgentRuntime**, a local embedded agent runtime implementation.
#
# Tomorrow we'll briefly look at a Distributed runtime.

# %%
from dataclasses import dataclass
from autogen_core import AgentId, MessageContext, RoutedAgent, message_handler
from autogen_core import SingleThreadedAgentRuntime
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.messages import TextMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### First we define our Message object
#
# Whatever structure we want for messages in our Agent framework.

# %%
# Let's have a simple one!

@dataclass
class Message:
    content: str

# %% [markdown]
# ### Now we define our Agent
#
# A subclass of RoutedAgent.
#
# Every Agent has an **Agent ID** which has 2 components:
# `agent.id.type` describes the kind of agent it is
# `agent.id.key` gives it its unique identifier
#
# Any method with the `@message_handler` decorated will have the opportunity to receive messages.

# %%
class SimpleAgent(RoutedAgent):
    def __init__(self) -> None:
        super().__init__("Simple")

    @message_handler
    async def on_my_message(self, message: Message, ctx: MessageContext) -> Message:
        return Message(content=f"This is {self.id.type}-{self.id.key}. You said '{message.content}' and I disagree.")

# %% [markdown]
# ### OK let's create a Standalone runtime and register our agent type

# %%
runtime = SingleThreadedAgentRuntime()
await SimpleAgent.register(runtime, "simple_agent", lambda: SimpleAgent())
# Out:
# AgentType(type='simple_agent')

# %% [markdown]
# ### Alright! Let's start a runtime and send a message

# %%
runtime.start()

# %%
agent_id = AgentId("simple_agent", "default")
response = await runtime.send_message(Message("Well hi there!"), agent_id)
print(">>>", response.content)
# Out:
# >>> This is simple_agent-default. You said 'Well hi there!' and I disagree.

# %%
await runtime.stop()
await runtime.close()

# %% [markdown]
# ### OK Now let's do something more interesting
#
# We'll use an AgentChat Assistant!

# %%
class MyLLMAgent(RoutedAgent):
    def __init__(self) -> None:
        super().__init__("LLMAgent")
        model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
        self._delegate = AssistantAgent("LLMAgent", model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        print(f"{self.id.type} received message: {message.content}")
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        reply = response.chat_message.content
        print(f"{self.id.type} responded: {reply}")
        return Message(content=reply)

# %%
from autogen_core import SingleThreadedAgentRuntime

runtime = SingleThreadedAgentRuntime()
await SimpleAgent.register(runtime, "simple_agent", lambda: SimpleAgent())
await MyLLMAgent.register(runtime, "LLMAgent", lambda: MyLLMAgent())
# Out:
# AgentType(type='LLMAgent')

# %%
runtime.start()  # Start processing messages in the background.
response = await runtime.send_message(Message("Hi there!"), AgentId("LLMAgent", "default"))
print(">>>", response.content)
response =  await runtime.send_message(Message(response.content), AgentId("simple_agent", "default"))
print(">>>", response.content)
response = await runtime.send_message(Message(response.content), AgentId("LLMAgent", "default"))
# Out:
# LLMAgent received message: Hi there!
# LLMAgent responded: Hello! How can I assist you today?
# >>> Hello! How can I assist you today?
# >>> This is simple_agent-default. You said 'Hello! How can I assist you today?' and I disagree.
# LLMAgent received message: This is simple_agent-default. You said 'Hello! How can I assist you today?' and I disagree.
# LLMAgent responded: I appreciate your feedback! How would you prefer me to respond?

# %%
await runtime.stop()
await runtime.close()

# %% [markdown]
# ### OK now let's show this at work - let's have 3 agents interact!

# %%
from autogen_ext.models.ollama import OllamaChatCompletionClient


class Player1Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OpenAIChatCompletionClient(model="gpt-4o-mini", temperature=1.0)
        self._delegate = AssistantAgent(name, model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)
    
class Player2Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OllamaChatCompletionClient(model="llama3.2", temperature=1.0)
        self._delegate = AssistantAgent(name, model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)

# %%
JUDGE = "You are judging a game of rock, paper, scissors. The players have made these choices:\n"

class RockPaperScissorsAgent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OpenAIChatCompletionClient(model="gpt-4o-mini", temperature=1.0)
        self._delegate = AssistantAgent(name, model_client=model_client)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        instruction = "You are playing rock, paper, scissors. Respond only with the one word, one of the following: rock, paper, or scissors."
        message = Message(content=instruction)
        inner_1 = AgentId("player1", "default")
        inner_2 = AgentId("player2", "default")
        response1 = await self.send_message(message, inner_1)
        response2 = await self.send_message(message, inner_2)
        result = f"Player 1: {response1.content}\nPlayer 2: {response2.content}\n"
        judgement = f"{JUDGE}{result}Who wins?"
        message = TextMessage(content=judgement, source="user")
        response = await self._delegate.on_messages([message], ctx.cancellation_token)
        return Message(content=result + response.chat_message.content)

# %%
runtime = SingleThreadedAgentRuntime()
await Player1Agent.register(runtime, "player1", lambda: Player1Agent("player1"))
await Player2Agent.register(runtime, "player2", lambda: Player2Agent("player2"))
await RockPaperScissorsAgent.register(runtime, "rock_paper_scissors", lambda: RockPaperScissorsAgent("rock_paper_scissors"))
runtime.start()

# %%
agent_id = AgentId("rock_paper_scissors", "default")
message = Message(content="go")
response = await runtime.send_message(message, agent_id)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[18], line 3
#       1 agent_id = AgentId("rock_paper_scissors", "default")
#       2 message = Message(content="go")
# ----> 3 response = await runtime.send_message(message, agent_id)
#       4 print(response.content)
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:385, in SingleThreadedAgentRuntime.send_message(self, message, recipient, sender, cancellation_token, message_id)
#     371 await self._message_queue.put(
#     372     SendMessageEnvelope(
#     373         message=message,
#    (...)    380     )
#     381 )
#     383 cancellation_token.link_future(future)
# --> 385 return await future
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:508, in SingleThreadedAgentRuntime._process_send(self, message_envelope)
#     496     with self._tracer_helper.trace_block(
#     497         "process",
#     498         recipient_agent.id,
#    (...)    505         ),
#     506     ):
#     507         with MessageHandlerContext.populate_context(recipient_agent.id):
# --> 508             response = await recipient_agent.on_message(
#     509                 message_envelope.message,
#     510                 ctx=message_context,
#     511             )
#     512 except CancelledError as e:
#     513     if not message_envelope.future.cancelled():
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_base_agent.py:119, in BaseAgent.on_message(self, message, ctx)
#     117 @final
#     118 async def on_message(self, message: Any, ctx: MessageContext) -> Any:
# --> 119     return await self.on_message_impl(message, ctx)
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_routed_agent.py:485, in RoutedAgent.on_message_impl(self, message, ctx)
#     483     for h in handlers:
#     484         if h.router(message, ctx):
# --> 485             return await h(self, message, ctx)
#     486 return await self.on_unhandled_message(message, ctx)
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_routed_agent.py:149, in message_handler.<locals>.decorator.<locals>.wrapper(self, message, ctx)
#     146     else:
#     147         logger.warning(f"Message type {type(message)} not in target types {target_types}")
# --> 149 return_value = await func(self, message, ctx)
#     151 if AnyType not in return_types and type(return_value) not in return_types:
#     152     if strict:
#
# Cell In[15], line 16, in RockPaperScissorsAgent.handle_my_message_type(self, message, ctx)
#      14 inner_2 = AgentId("player2", "default")
#      15 response1 = await self.send_message(message, inner_1)
# ---> 16 response2 = await self.send_message(message, inner_2)
#      17 result = f"Player 1: {response1.content}\nPlayer 2: {response2.content}\n"
#      18 judgement = f"{JUDGE}{result}Who wins?"
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_base_agent.py:136, in BaseAgent.send_message(self, message, recipient, cancellation_token, message_id)
#     133 if cancellation_token is None:
#     134     cancellation_token = CancellationToken()
# --> 136 return await self._runtime.send_message(
#     137     message,
#     138     sender=self.id,
#     139     recipient=recipient,
#     140     cancellation_token=cancellation_token,
#     141     message_id=message_id,
#     142 )
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:385, in SingleThreadedAgentRuntime.send_message(self, message, recipient, sender, cancellation_token, message_id)
#     371 await self._message_queue.put(
#     372     SendMessageEnvelope(
#     373         message=message,
#    (...)    380     )
#     381 )
#     383 cancellation_token.link_future(future)
# --> 385 return await future
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_single_threaded_agent_runtime.py:508, in SingleThreadedAgentRuntime._process_send(self, message_envelope)
#     496     with self._tracer_helper.trace_block(
#     497         "process",
#     498         recipient_agent.id,
#    (...)    505         ),
#     506     ):
#     507         with MessageHandlerContext.populate_context(recipient_agent.id):
# --> 508             response = await recipient_agent.on_message(
#     509                 message_envelope.message,
#     510                 ctx=message_context,
#     511             )
#     512 except CancelledError as e:
#     513     if not message_envelope.future.cancelled():
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_base_agent.py:119, in BaseAgent.on_message(self, message, ctx)
#     117 @final
#     118 async def on_message(self, message: Any, ctx: MessageContext) -> Any:
# --> 119     return await self.on_message_impl(message, ctx)
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_routed_agent.py:485, in RoutedAgent.on_message_impl(self, message, ctx)
#     483     for h in handlers:
#     484         if h.router(message, ctx):
# --> 485             return await h(self, message, ctx)
#     486 return await self.on_unhandled_message(message, ctx)
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_core/_routed_agent.py:149, in message_handler.<locals>.decorator.<locals>.wrapper(self, message, ctx)
#     146     else:
#     147         logger.warning(f"Message type {type(message)} not in target types {target_types}")
# --> 149 return_value = await func(self, message, ctx)
#     151 if AnyType not in return_types and type(return_value) not in return_types:
#     152     if strict:
#
# Cell In[14], line 25, in Player2Agent.handle_my_message_type(self, message, ctx)
#      22 @message_handler
#      23 async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
#      24     text_message = TextMessage(content=message.content, source="user")
# ---> 25     response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
#      26     return Message(content=response.chat_message.content)
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_agentchat/agents/_assistant_agent.py:896, in AssistantAgent.on_messages(self, messages, cancellation_token)
#     882 async def on_messages(
#     883     self,
#     884     messages: Sequence[BaseChatMessage],
#     885     cancellation_token: CancellationToken,
#     886 ) -> Response:
#     887     """Process incoming messages and generate a response.
#     888
#     889     Args:
#    (...)    894         Response containing the agent's reply
#     895     """
# --> 896     async for message in self.on_messages_stream(messages, cancellation_token):
#     897         if isinstance(message, Response):
#     898             return message
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_agentchat/agents/_assistant_agent.py:953, in AssistantAgent.on_messages_stream(self, messages, cancellation_token)
#     951 # STEP 4: Run the first inference
#     952 model_result = None
# --> 953 async for inference_output in self._call_llm(
#     954     model_client=model_client,
#     955     model_client_stream=model_client_stream,
#     956     system_messages=system_messages,
#     957     model_context=model_context,
#     958     workbench=workbench,
#     959     handoff_tools=handoff_tools,
#     960     agent_name=agent_name,
#     961     cancellation_token=cancellation_token,
#     962     output_content_type=output_content_type,
#     963     message_id=message_id,
#     964 ):
#     965     if isinstance(inference_output, CreateResult):
#     966         model_result = inference_output
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_agentchat/agents/_assistant_agent.py:1109, in AssistantAgent._call_llm(cls, model_client, model_client_stream, system_messages, model_context, workbench, handoff_tools, agent_name, cancellation_token, output_content_type, message_id)
#    1107     yield model_result
#    1108 else:
# -> 1109     model_result = await model_client.create(
#    1110         llm_messages,
#    1111         tools=tools,
#    1112         cancellation_token=cancellation_token,
#    1113         json_output=output_content_type,
#    1114     )
#    1115     yield model_result
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/autogen_ext/models/ollama/_ollama_client.py:646, in BaseOllamaChatCompletionClient.create(self, messages, tools, tool_choice, json_output, extra_create_args, cancellation_token)
#     644 if cancellation_token is not None:
#     645     cancellation_token.link_future(future)
# --> 646 result: ChatResponse = await future
#     648 usage = RequestUsage(
#     649     # TODO backup token counting
#     650     prompt_tokens=result.prompt_eval_count if result.prompt_eval_count is not None else 0,
#     651     completion_tokens=(result.eval_count if result.eval_count is not None else 0),
#     652 )
#     654 logger.info(
#     655     LLMCallEvent(
#     656         messages=[m.model_dump() for m in create_params.messages],
#    (...)    660     )
#     661 )
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/ollama/_client.py:953, in AsyncClient.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     907 async def chat(
#     908   self,
#     909   model: str = '',
#    (...)    917   keep_alive: Optional[Union[float, str]] = None,
#     918 ) -> Union[ChatResponse, AsyncIterator[ChatResponse]]:
#     919   """
#     920   Create a chat response using the requested model.
#     921
#    (...)    950   Returns `ChatResponse` if `stream` is `False`, otherwise returns an asynchronous `ChatResponse` generator.
#     951   """
# --> 953   return await self._request(
#     954     ChatResponse,
#     955     'POST',
#     956     '/api/chat',
#     957     json=ChatRequest(
#     958       model=model,
#     959       messages=list(_copy_messages(messages)),
#     960       tools=list(_copy_tools(tools)),
#     961       stream=stream,
#     962       think=think,
#     963       format=format,
#     964       options=options,
#     965       keep_alive=keep_alive,
#     966     ).model_dump(exclude_none=True),
#     967     stream=stream,
#     968   )
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/ollama/_client.py:751, in AsyncClient._request(self, cls, stream, *args, **kwargs)
#     747         yield cls(**part)
#     749   return inner()
# --> 751 return cls(**(await self._request_raw(*args, **kwargs)).json())
#
# File ~/Documents/documents/Personals/agentic-ai-projects/agents/.venv/lib/python3.12/site-packages/ollama/_client.py:697, in AsyncClient._request_raw(self, *args, **kwargs)
#     695   raise ResponseError(e.response.text, e.response.status_code) from None
#     696 except httpx.ConnectError:
# --> 697   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ConnectionError: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download

# %%
await runtime.stop()
await runtime.close()
