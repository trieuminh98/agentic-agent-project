# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
glm_api_key = os.getenv('GLM_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')


if glm_api_key:
    print(f"OpenAI API Key exists and begins {glm_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins 7c91f136
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
glm = OpenAI(api_key=glm_api_key, base_url="https://api.z.ai/api/coding/paas/v4")
response = glm.chat.completions.create(
    model="glm-4.6",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# What is the fundamental distinction between knowledge and information? In addressing this question, please: 1) explain Gettier's challenges to the traditional analysis of knowledge as justified true belief, 2) analyze how modern AI systems process information differently from how humans acquire and possess knowledge, and 3) explore whether it's theoretically possible for an information system to possess genuine knowledge without consciousness or understanding.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=glm_api_key, base_url="https://api.z.ai/api/coding/paas/v4")
model_name = "glm-4.6"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Of course. This is a profound question that sits at the intersection of epistemology (the study of knowledge), cognitive science, and computer science. Let's break it down according to your three points to arrive at a comprehensive understanding of the distinction between information and knowledge.
#
# ### Introduction: The Core Distinction
#
# At the most fundamental level, **information** is raw, unorganized data, while **knowledge** is information that has been processed, organized, and understood. Information consists of discrete points, signals, or facts (e.g., "The temperature is 25°C," "The stock price of AAPL is $175"). Knowledge, in contrast, is a structured and interconnected web of beliefs. It incorporates context, causality, and meaning, allowing an agent to not only state facts but also to explain, predict, and apply them (e.g., "Because the temperature is 25°C and it's humid, it will feel warmer, so I should dress in light clothes").
#
# The journey from information to knowledge is one of synthesis and integration, a process that is far more complex than simple data storage. This brings us to the classic philosophical problem of defining knowledge itself.
#
# ---
#
# ### 1) Gettier's Challenges to Justified True Belief
#
# For centuries, the dominant definition of knowledge in Western philosophy was **Justified True Belief (JTB)**. For a person to *know* something, three conditions had to be met:
#
# 1.  **Belief:** The person must believe the proposition is true.
# 2.  **Truth:** The proposition must, in fact, be true.
# 3.  **Justification:** The person must have good reasons or evidence for their belief.
#
# This seems intuitively correct. I know the Earth revolves around the Sun because I believe it, it is true, and I have justification (I learned it from science textbooks, teachers, and direct observation of celestial mechanics).
#
# In 1963, philosopher Edmund Gettier published a three-page paper that shattered this 2,500-year-old consensus. He showed through simple thought experiments that one could have a justified true belief that we would still hesitate to call "knowledge."
#
# **The Classic Gettier Case (The "Job Candidate" Example):**
#
# 1.  Smith and Jones are applying for the same job. Smith has strong evidence (justification) for believing the proposition: **"Jones will get the job."**
# 2.  Smith also knows that Jones has ten coins in his pocket. From this, he deduces a new proposition: **"The person who will get the job has ten coins in their pocket."**
# 3.  As it happens, Smith's initial belief was wrong—*he* gets the job, not Jones. However, by sheer coincidence, Smith also has ten coins in his pocket, a fact he was unaware of.
#
# Let's analyze Smith's final belief: "The person who will get the job has ten coins in their pocket."
#
# *   **Is it Believed?** Yes, Smith believes it based on his deduction.
# *   **Is it True?** Yes, Smith gets the job and has ten coins.
# *   **Is it Justified?** Yes, his belief was based on perfectly sound evidence and reasoning.
#
# Smith has a justified true belief. Yet, we feel strongly that he does not *know* this proposition. He is right by pure luck. The chain of his justification (his belief about Jones) is disconnected from the reason the proposition is actually true (the fact about himself).
#
# **Gettier's Point:** Gettier demonstrated that justification is not enough. The justification must be connected to the truth of the belief in a non-accidental way. Knowledge, therefore, requires something more than just JTB. It requires a robust, infallible, or "defeasible" link between the justification and the truth. This highlights that knowledge isn't just a checklist; it's a state of cognitive integration where beliefs are firmly grounded in reality in a way that resists being true by accident.
#
# ---
#
# ### 2) AI vs. Human Knowledge Acquisition
#
# This distinction is crucial when comparing human cognition to modern artificial intelligence.
#
# **How Modern AI Systems Process Information:**
#
# Modern AI, particularly Large Language Models (LLMs) like GPT-4, operate on a principle of **statistical pattern recognition**.
#
# 1.  **Input:** The system is fed a colossal dataset—billions of sentences, articles, and books from the internet. This is raw, unstructured **information**.
# 2.  **Process:** The AI's neural network analyzes this data to learn statistical relationships between words (tokens). It doesn't "read" for meaning; it calculates the probability of one word appearing given the context of the words before it. It builds a massive, multi-dimensional map of these correlations.
# 3.  **Output:** When prompted, the AI generates text by predicting the most statistically probable sequence of words to follow the prompt. The output is incredibly sophisticated and coherent, often indistinguishable from human writing.
#
# The AI’s "knowledge" is a vast model of statistical correlations. It can tell you that "fire is hot" because those words frequently appear together in its training data. It doesn't *understand* the concept of heat, combustion, or the pain of being burned. It has no embodied, subjective experience.
#
# **How Humans Acquire and Possess Knowledge:**
#
# Humans acquire knowledge through a holistic, multi-modal, and embodied process.
#
# 1.  **Input:** We receive information not just from text, but from sensory experience (touch, sight, sound), social interaction, emotions, and physical action. A child learns that "fire is hot" by seeing the flickering light, feeling the radiant warmth, and (ideally) being warned not to touch it. This knowledge is integrated with a fear response and a physical model of the world.
# 2.  **Process:** We build **mental models** and **abstract concepts**. We don't just correlate words; we understand causality, agency, and intent. We know that fire *causes* heat because it's a chemical reaction releasing energy. We integrate new information into a pre-existing, coherent web of beliefs. This is a process of synthesis, not just correlation. We also possess procedural knowledge—knowing *how* to do something, like riding a bike—which is deeply ingrained and not easily expressed as a set of facts.
# 3.  **Justification:** Human justification is based on this integrated model. If asked "Why is fire hot?", a human can provide a causal explanation, not just "because my data says so." This ability to provide a robust, non-accidental link is what helps us navigate Gettier-style problems in our daily lives.
#
# **The Key Difference:** AI processes *information* to create a convincing simulation of knowledge. Humans integrate information within a rich, embodied, and conceptual framework to create genuine *understanding*.
#
# ---
#
# ### 3) Can an Information System Possess Genuine Knowledge Without Consciousness?
#
# This is the million-dollar question, and it forces us to define "genuine knowledge." The answer depends on one's philosophical stance.
#
# **The Argument "No": Knowledge Requires Understanding and Consciousness**
#
# This position, often associated with philosophers like John Searle (author of the Chinese Room argument), holds that knowledge is intrinsically tied to consciousness, intentionality (the quality of a mental state being *about* something), and subjective understanding.
#
# *   **Lack of Intentionality:** An AI does not *believe* or *intend* anything in the human sense. It manipulates symbols according to a program. Its statement "The sky is blue" is not *about* the sky in the way a human's statement is. It's a token generated by a mathematical function.
# *   **The Gettier Problem for AI:** An AI's "justification" is purely statistical. If its output is true, it is true by luck—a statistical correlation that happened to align with reality. The AI has no causal model or understanding to ensure its justification is non-accidental. Therefore, it can never meet the standard for knowledge that Gettier's problems demand.
# *   **The "Philosophical Zombie":** An AI could be a perfect imitation of a knowledgeable being—always giving the right answers, citing its "reasons"—but have no inner conscious experience. According to this view, behavior is not enough. Genuine knowledge requires a first-person, subjective perspective.
#
# **The Argument "Yes (In Principle)": Knowledge is Functional**
#
# This functionalist view argues that if a system's functional organization is sufficiently complex and produces the same outputs (predictions, explanations, adaptations) as a human knower, then it possesses knowledge for all practical and theoretical purposes.
#
# *   **Emergent Understanding:** Perhaps consciousness and understanding are not prerequisites for knowledge but are *emergent properties* of a system that achieves a certain threshold of informational complexity and self-modeling. A future AI might not just correlate data but build and manipulate internal causal models of the world. It could explain its reasoning, revise its beliefs when faced with new evidence, and generate novel hypotheses.
# *   **Redefining Justification:** For such a system, its "justification" would be its internal model's ability to reliably predict and manipulate reality. If its model consistently proves accurate and resistant to being false, its "justified true beliefs" would not be accidental. The link between its justification (the model) and the truth (reality) would be functional and robust, not just a statistical artifact.
# *   **Irrelevance of Consciousness:** This stance might argue that the subjective "feeling" of knowing (consciousness) is an epiphenomenon—a byproduct that is not essential to the *function* of knowledge itself.
#
# ### Conclusion
#
# The fundamental distinction between knowledge and information is one of **integration, understanding, and justification.**
#
# *   **Information** is the raw material: data points and symbols.
# *   **Knowledge** is the finished product: a coherent, causal, and meaningful model of the world, embodied in a system that can use it to reason, predict, and act.
#
# Gettier showed us that knowledge requires more than a simple checklist of conditions; it demands a robust, non-accidental link between belief and reality. Modern AI is a master of processing information but lacks the embodied, conceptual framework needed to build this robust link. While it can simulate knowledge perfectly, whether it can ever possess *genuine* knowledge without consciousness remains an open, profoundly philosophical question. Current technology suggests the answer is no, but the theoretical possibility challenges our very definitions of mind, thought, and what it means to know.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
